# %%
from google.colab import drive
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Mount Google Drive
drive.mount('/content/drive')

# Define data generators
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# Set up the path to the dataset folder on Google Drive
train_path = '/content/drive/MyDrive/Dataset/violence_dataset'

# Generate batches of augmented data
train_generator = train_datagen.flow_from_directory(train_path, target_size=(64, 64), batch_size=32, class_mode='binary')

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(64, 64, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(units=128, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_generator, epochs=10)

# Save the model
model.save('/content/drive/MyDrive/violence_detection_model.h5')
# Out:
# Mounted at /content/drive
# Found 4001 images belonging to 2 classes.
# Epoch 1/10
# 126/126 [==============================] - 542s 4s/step - loss: 0.5134 - accuracy: 0.7503
# Epoch 2/10
# 126/126 [==============================] - 51s 405ms/step - loss: 0.4099 - accuracy: 0.8098
# Epoch 3/10
# 126/126 [==============================] - 50s 395ms/step - loss: 0.2979 - accuracy: 0.8693
# Epoch 4/10
# 126/126 [==============================] - 50s 396ms/step - loss: 0.2482 - accuracy: 0.8950
# Epoch 5/10
# 126/126 [==============================] - 50s 394ms/step - loss: 0.2061 - accuracy: 0.9178
# Epoch 6/10
# 126/126 [==============================] - 51s 403ms/step - loss: 0.1731 - accuracy: 0.9353
# Epoch 7/10
# 126/126 [==============================] - 51s 407ms/step - loss: 0.1463 - accuracy: 0.9445
# Epoch 8/10
# 126/126 [==============================] - 51s 403ms/step - loss: 0.1451 - accuracy: 0.9480
# Epoch 9/10
# ...
